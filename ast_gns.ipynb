# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi

# %%
# %cd /content/drive/MyDrive/ST-GCN
# Out:
# /content/drive/MyDrive/ST-GCN

# %%
# !pwd
# Out:
# /content/drive/MyDrive/ST-GCN

# %%
# %cd torchlight
# Out:
# /content/drive/MyDrive/ST-GCN/torchlight

# %%
# !pwd
# Out:
# /content/drive/MyDrive/ST-GCN/torchlight

# %%
# %ls
# Out:
# build/  __init__.py   setup.py     torchlight.egg-info/
# dist/   __pycache__/  torchlight/

# %%
# !python setup.py install

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/ST-GCN

# %%
# %cd /content/
# Out:
# /content

# %%
# !mkdir data

# %%
# !unzip -l /content/drive/MyDrive/kinetics-skeleton.zip
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/kinetics-skeleton/kinetics-skeleton.zip, /content/drive/MyDrive/kinetics-skeleton/kinetics-skeleton.zip.zip or /content/drive/MyDrive/kinetics-skeleton/kinetics-skeleton.zip.ZIP.

# %%
# !unzip  -d /content/data

# %%
# !unzip /content/drive/MyDrive/kinetics-skeleton.zip "kinetics-skeleton/kinetics_val/*" -d "/content/data"

# %%
# !unzip /content/drive/MyDrive/kinetics-skeleton.zip "kinetics-skeleton/kinetics_train/*" -d "/content/data"

# %%
# !unzip /content/drive/MyDrive/kinetics-skeleton.zip "kinetics-skeleton/kinetics_val_label.json" -d "/content/data"
# Out:
# Archive:  /content/drive/MyDrive/kinetics-skeleton.zip
#   inflating: /content/data/kinetics-skeleton/kinetics_val_label.json

# %%
# %cd /content/drive/MyDrive/ST-GCN
# Out:
# /content/drive/MyDrive/ST-GCN

# %%
# %rm /content/data/kinetics-skeleton/kinetics_val/V8TAMu4zSl4.json

# %%
# %rm /content/data/kinetics-skeleton/kinetics_train/V8TAMu4zSl4.json

# %%
# %rm /content/data/kinetics-skeleton/kinetics_train/TFySoeQK5c0.json

# %%
# %rm /content/data/kinetics-skeleton/kinetics_train/jCB1bpxQSn0.json

# %%
# !python3 tools/kinetics_gendata.py --data_path /content/data/kinetics-skeleton
# Out:
# Streaming output truncated to the last 5000 lines.
# s3dK8R-jzac.json
# Zk_4N83fkx4.json
# 9gHBzb1m_7U.json
# IQu6ugfzjB0.json
# cL389d29hq8.json
# p50nL6cAwrU.json
# -XJd1dTgslI.json
# MlqgQRlzggk.json
# r64vcV2AkNE.json
# UUjg86AnoOg.json
# NVAuLnPUsgo.json
# Y9WjlhlcmJs.json
# PxrZJ5LeXtE.json
# luLGODGnXMc.json
# Ypf22ZfvAhM.json
# bUidM8i-buc.json
# m6egJx457Ng.json
# zHtZV7K0CmY.json
# pGFSjcl2EBE.json
# G6z9eP01n4c.json
# JS4pPxUwxPk.json
# za4X6aZSjVk.json
# YgXLcOtQcSg.json
# Of6LQZ7jGaM.json
# xNDArxGeQCg.json
# egZqefmMHOQ.json
# Bc2iSXI37jk.json
# SQCsXDtiARU.json
# pGnzgjtqsD4.json
# jXgvoYqblMM.json
# LBgRTCVwyik.json
# wSVBbmPbdzw.json
# hcERxtbIobo.json
# Zb-uglFoLCc.json
# A1KezXIlxP0.json
# I6IAqeWUkq0.json
# Qax4NxHP0s4.json
# 9f3aeZnmufc.json
# CXiVTwPsgGw.json
# wTRmSOdLc5E.json
# eVh0SypU4tA.json
# 8gM0pPYkx0U.json
# Vt6hfbMUzWc.json
# bAx4K1SR3gs.json
# W_L_UlXohu8.json
# YLVZShRe1P8.json
# RtYq7w91SyA.json
# abVIgtfR9sY.json
# K2Us8b8W4bk.json
# ...

# %%
# %ls
# Out:
# config/  feeder/  models/  processor/        resource/  torchlight/
# data/    main.py  net/     requirements.txt  tools/     work_dir/

# %%
import sys
sys.path.insert(0, '/content/drive/MyDrive/ST-GCN/torchlight')

# %%
# !pip3 install scikit-video
# Out:
# ...
#      |████████████████████████████████| 2.3 MB 14.5 MB/s
# ...

# %%
# !python3 main.py recognition -h

# %%
# !python3 main.py recognition -c config/st_gcn/kinetics-skeleton/train.yaml --save_result True
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [05.19.22|20:57:04] Parameters:
# ...

# %%
# !python main.py recognition -c config/st_gcn/kinetics-skeleton/test.yaml --use_gpu True
# Out:
# [05.20.22|13:48:57] Load weights from ./work_dir/recognition/kinetics_skeleton/ST_GCN/epoch4_model.pt.
# [05.20.22|13:48:57] Load weights [A].
# [05.20.22|13:48:57] Load weights [data_bn.weight].
# [05.20.22|13:48:57] Load weights [data_bn.bias].
# [05.20.22|13:48:57] Load weights [data_bn.running_mean].
# [05.20.22|13:48:57] Load weights [data_bn.running_var].
# [05.20.22|13:48:57] Load weights [data_bn.num_batches_tracked].
# [05.20.22|13:48:57] Load weights [st_gcn_networks.0.gcn.conv.weight].
# [05.20.22|13:48:57] Load weights [st_gcn_networks.0.gcn.conv.bias].
# [05.20.22|13:48:57] Load weights [st_gcn_networks.0.tcn.0.weight].
# [05.20.22|13:48:57] Load weights [st_gcn_networks.0.tcn.0.bias].
# [05.20.22|13:48:57] Load weights [st_gcn_networks.0.tcn.0.running_mean].
# [05.20.22|13:48:57] Load weights [st_gcn_networks.0.tcn.0.running_var].
# [05.20.22|13:48:57] Load weights [st_gcn_networks.0.tcn.0.num_batches_tracked].
# ...

# %%
loss = '''
[05.19.22|20:57:16] 	Iter 0 Done. | loss: 6.1032 | lr: 0.010000
[05.19.22|21:12:17] 	Iter 100 Done. | loss: 5.8749 | lr: 0.010000
[05.19.22|21:27:19] 	Iter 200 Done. | loss: 5.8647 | lr: 0.010000
[05.19.22|21:42:14] 	Iter 300 Done. | loss: 5.9869 | lr: 0.010000
[05.19.22|21:57:06] 	Iter 400 Done. | loss: 5.7405 | lr: 0.010000
[05.19.22|22:12:01] 	Iter 500 Done. | loss: 5.5746 | lr: 0.010000
[05.19.22|22:26:56] 	Iter 600 Done. | loss: 5.8706 | lr: 0.010000
[05.19.22|22:41:48] 	Iter 700 Done. | loss: 5.8615 | lr: 0.010000
[05.19.22|22:56:31] 	Iter 800 Done. | loss: 5.7258 | lr: 0.010000
[05.19.22|23:11:14] 	Iter 900 Done. | loss: 5.6072 | lr: 0.010000
[05.20.22|06:17:17] 	Iter 3800 Done. | loss: 5.6927 | lr: 0.010000
[05.20.22|06:32:01] 	Iter 3900 Done. | loss: 5.2054 | lr: 0.010000
[05.20.22|06:46:51] 	Iter 4000 Done. | loss: 5.3877 | lr: 0.010000
[05.20.22|07:01:37] 	Iter 4100 Done. | loss: 5.4191 | lr: 0.010000
[05.20.22|07:16:21] 	Iter 4200 Done. | loss: 5.5026 | lr: 0.010000
[05.20.22|07:30:48] 	Iter 4300 Done. | loss: 5.2013 | lr: 0.010000
[05.20.22|07:45:13] 	Iter 4400 Done. | loss: 5.5212 | lr: 0.010000
[05.20.22|07:59:48] 	Iter 4500 Done. | loss: 5.3542 | lr: 0.010000
[05.20.22|08:14:25] 	Iter 4600 Done. | loss: 5.5695 | lr: 0.010000
[05.20.22|08:25:50] 	mean_loss: 5.379183032268133
[05.20.22|08:25:50] Time consumption:
[05.20.22|08:25:50] Done.
[05.20.22|08:25:50] Training epoch: 3
[05.20.22|08:28:53] 	Iter 4700 Done. | loss: 5.1655 | lr: 0.010000
[05.20.22|08:43:13] 	Iter 4800 Done. | loss: 5.4270 | lr: 0.010000
[05.20.22|08:57:40] 	Iter 4900 Done. | loss: 5.2011 | lr: 0.010000
[05.20.22|09:12:05] 	Iter 5000 Done. | loss: 5.3217 | lr: 0.010000
[05.20.22|09:26:38] 	Iter 5100 Done. | loss: 5.2791 | lr: 0.010000
[05.20.22|09:41:14] 	Iter 5200 Done. | loss: 5.3866 | lr: 0.010000
[05.20.22|09:55:43] 	Iter 5300 Done. | loss: 5.2872 | lr: 0.010000
[05.20.22|10:10:17] 	Iter 5400 Done. | loss: 5.5470 | lr: 0.010000
[05.20.22|10:24:46] 	Iter 5500 Done. | loss: 5.8662 | lr: 0.010000
[05.20.22|10:39:15] 	Iter 5600 Done. | loss: 5.7802 | lr: 0.010000
[05.20.22|10:53:54] 	Iter 5700 Done. | loss: 4.9899 | lr: 0.010000
[05.20.22|11:08:48] 	Iter 5800 Done. | loss: 5.4922 | lr: 0.010000
[05.20.22|11:23:44] 	Iter 5900 Done. | loss: 5.1011 | lr: 0.010000
[05.20.22|11:38:33] 	Iter 6000 Done. | loss: 4.8722 | lr: 0.010000
[05.20.22|11:53:08] 	Iter 6100 Done. | loss: 5.4271 | lr: 0.010000
[05.20.22|12:07:37] 	Iter 6200 Done. | loss: 5.2089 | lr: 0.010000
[05.20.22|12:13:15] 	mean_loss: 5.2979071806638665
[05.20.22|12:13:15] Time consumption:
'''

# %%
np.arange(0, 3, 1, dtype=int)
# Out:
# array([0, 1, 2])

# %%
import re
import matplotlib.pyplot as plt
import numpy as np

losses = re.findall(r'mean_loss: (.*?)\n', loss)
ls = []
for l in losses:
  if l!='':
    ls.append(float(l))
plt.figure(figsize=(6,6))
plt.plot(np.arange(0, 4, 1, dtype=int), ls)
plt.title("Validation Loss")
plt.xlabel("step")
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')
